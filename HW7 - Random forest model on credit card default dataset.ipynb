# %% [markdown]
# #### Imports

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

import numpy as np
import pandas as pd

# %% [markdown]
# ### Exploratory Data Analysis & Data Setup

# %%
df = pd.read_csv(r"C:\Users\dmoha\Downloads\ccdefault.csv")
df = df.dropna()

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2       3913       3102        689          0          0
# 1      0      2       2682       1725       2682       3272       3455
# 2      0      0      29239      14027      13559      14331      14948
# 3      0      0      46990      48233      49291      28314      28959
# 4      0      0       8617       5670      35835      20940      19146
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
X = df.iloc[:, 1:-1]
y = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# %% [markdown]
# ### Part 1: Random forest estimators
# Fit a random forest model, try several different values for N_estimators, report in-sample accuracies.

# %%
rf = RandomForestClassifier()

params_rf = {
    'n_estimators': (10, 20, 100),
#    'max_features': ('log2', 'auto', 'sqrt'),
    'min_samples_leaf': (2, 10, 30)
}

grid_rf = GridSearchCV(estimator=rf,
                       param_grid=params_rf,
                       scoring="roc_auc",
                       cv=10,
                       n_jobs=-1)

grid_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'n_estimators': (10, 20, 100), 'min_samples_leaf': (2, 10, 30)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
best_model = grid_rf.best_estimator_
y_pred_test = best_model.predict(X_test)


rmse_test = MSE(y_test, y_pred_test)**.5
print('Test RMSE of best model: {:.3f}'.format(rmse_test)) 

y_pred_train = best_model.predict(X_train)
rmse_test = MSE(y_train, y_pred_train)**.5
print('Train RMSE of best model: {:.3f}'.format(rmse_test))
# Out:
# Test RMSE of best model: 0.425
# Train RMSE of best model: 0.414

# %%
print(grid_rf.best_score_)
print(grid_rf.best_params_)
# Out:
# 0.7844265466206186
# {'min_samples_leaf': 30, 'n_estimators': 100}

# %%
allscores=grid_rf.cv_results_['mean_test_score']
print(allscores)
# Out:
# [0.74550764 0.75997421 0.77145716 0.76724212 0.77302089 0.78094252
#  0.77641847 0.78010394 0.78442655]

# %% [markdown]
# ### Part 2: Random forest feature importance
# Display the individual feature importance of your best model in Part 1 above using the code presented in Chapter 4 on page 136. {importances=forest.feature_importances_ }

# %%
importances=best_model.feature_importances_ 
X_columns = list(X.columns.values.tolist())

featureImportances_DF = pd.DataFrame(
        {
            'Feature': X_columns,
            'Importance': importances
        })
featureImportances_DF.sort_values("Importance", ascending = False)
# Out:
#       Feature  Importance
# 5       PAY_0    0.292211
# 6       PAY_2    0.129108
# 7       PAY_3    0.075138
# 8       PAY_4    0.050836
# 17   PAY_AMT1    0.043840
# 0   LIMIT_BAL    0.038257
# 9       PAY_5    0.037577
# 18   PAY_AMT2    0.032597
# 11  BILL_AMT1    0.031155
# 10      PAY_6    0.030292
# 19   PAY_AMT3    0.028957
# 12  BILL_AMT2    0.027831
# 20   PAY_AMT4    0.024259
# 22   PAY_AMT6    0.021874
# 13  BILL_AMT3    0.021726
# 21   PAY_AMT5    0.021076
# 15  BILL_AMT5    0.020684
# 14  BILL_AMT4    0.020287
# 16  BILL_AMT6    0.019786
# 4         AGE    0.019036
# 2   EDUCATION    0.005201
# 1         SEX    0.004281
# 3    MARRIAGE    0.003990
